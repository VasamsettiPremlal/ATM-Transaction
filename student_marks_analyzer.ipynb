# %%
import numpy as np
n = int(input("Enter number of students: "))
marks_list = []
for i in range(n):
    mark = float(input(f"Enter marks for student {i+1}: "))
    marks_list.append(mark)
marks_array = np.array(marks_list)
total_marks = np.sum(marks_array)
average_marks = np.mean(marks_array)
highest_marks = np.max(marks_array)
lowest_marks = np.min(marks_array)
def assign_grade(avg):
    if avg > 85:
        return "A"
    elif avg >= 70:
        return "B"
    elif avg >= 50:
        return "C"
    else:
        return "Fail"
grade = assign_grade(average_marks)
print("----- Student Marks Analysis -----")
print("Marks:", marks_array)
print("Total Marks:", total_marks)
print("Average Marks:", average_marks)
print("Highest Marks:", highest_marks)
print("Lowest Marks:", lowest_marks)
print("Grade:", grade)
# Out:
# Enter number of students: 5
# Enter marks for student 1: 47
# Enter marks for student 2: 88
# Enter marks for student 3: 68
# Enter marks for student 4: 66
# Enter marks for student 5: 99
#
# ----- Student Marks Analysis -----
# Marks: [47. 88. 68. 66. 99.]
# Total Marks: 368.0
# Average Marks: 73.6
# Highest Marks: 99.0
# Lowest Marks: 47.0
# Grade: B
